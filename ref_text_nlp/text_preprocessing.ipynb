# %%
import torch
print(torch.__version__)
# Out:
# 2.7.0

# %%
print(torch.__version__)
# Out:
# 2.7.0

# %%
pip install torch==2.7.0 torchtext==0.22.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached torch-2.7.0-cp39-none-macosx_11_0_arm64.whl (68.6 MB)
# ERROR: Could not find a version that satisfies the requirement torchtext==0.22.0 (from versions: 0.1.1, 0.2.0, 0.2.1, 0.2.3, 0.3.1, 0.4.0, 0.5.0, 0.6.0, 0.10.0, 0.11.2, 0.12.0, 0.13.0, 0.13.1, 0.14.0, 0.14.1, 0.15.0, 0.15.1, 0.15.2, 0.16.0, 0.16.1, 0.16.2, 0.17.0, 0.17.1, 0.17.2, 0.18.0)
# ERROR: No matching distribution found for torchtext==0.22.0
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import torchtext
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /Users/phuongnguyen/Documents/Code Github/deep-learning-pytorch-projects/ref_text_nlp/text_preprocessing.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/phuongnguyen/Documents/Code%20Github/deep-learning-pytorch-projects/ref_text_nlp/text_preprocessing.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> import torchtext
#
# File ~/Library/Python/3.9/lib/python/site-packages/torchtext/__init__.py:6
#       3 from torch.hub import _get_torch_home
#       5 # the following import has to happen first in order to load the torchtext C++ library
# ----> 6 from torchtext import _extension  # noqa: F401
#       8 _TEXT_BUCKET = "https://download.pytorch.org/models/text/"
#      10 _CACHE_DIR = os.path.expanduser(os.path.join(_get_torch_home(), "text"))
#
# File ~/Library/Python/3.9/lib/python/site-packages/torchtext/_extension.py:64
# ...

# %% [markdown]
# **Text processing pipeline**
# 1. Raw data
#
# 2. Preprocessing: Clean and prepare text
# - Techniques:
# + Tokenization: tokens or words are extracted from text. Tokenziation using torchtext
# + Stop word removal: eliminate words that do not contribute to the meaning. Ex: 'a', 'the', 'and', 'or',...
# + Stemming: reducing words to their base form. Ex: 'runing' 'runs' 'run' becoms 'run'
# + Rare word removal: removing infrequent words that don't add value
#
# 3. Encoding: Convert text into machine-readable numbers. Enable analysis and modeling
# - Techniques:
# + One-hot encoding: transforms words into unique numerical representations
# + Bag-of-words (BoW): captures word frequency, disregarding order
# + TF-IDF: balances uniqueness and importance
# + Embedding: converts words into vectors, capturing semantic meaning
#
# 4. Dataset & Dataloader
# - Dataset as a container for processed and encoded text
# - DataLoader: batching, shuffling and multiprocessing

# %% [markdown]
# **2. PREPROCESSING**
#
# Techniques:
# + Tokenization: tokens or words are extracted from text. Tokenziation using torchtext
# + Stop word removal: eliminate words that do not contribute to the meaning. Ex: 'a', 'the', 'and', 'or',...
# + Stemming: reducing words to their base form. Ex: 'runing' 'runs' 'run' becoms 'run'
# + Rare word removal: removing infrequent words that don't add value

# %%
# Tokenization
from torchtext.data.utils import get_tokenizer
tokenizer = get_tokenizer("basic_english")
tokens = tokenizer("I am reading a book now. I love to read books!")
print(tokens)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /Users/phuongnguyen/Documents/Code Github/deep-learning-pytorch-projects/ref_text_nlp/text_preprocessing.ipynb Cell 5 line 2
#       <a href='vscode-notebook-cell:/Users/phuongnguyen/Documents/Code%20Github/deep-learning-pytorch-projects/ref_text_nlp/text_preprocessing.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> # Tokenization
# ----> <a href='vscode-notebook-cell:/Users/phuongnguyen/Documents/Code%20Github/deep-learning-pytorch-projects/ref_text_nlp/text_preprocessing.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> from torchtext.data.utils import get_tokenizer
#       <a href='vscode-notebook-cell:/Users/phuongnguyen/Documents/Code%20Github/deep-learning-pytorch-projects/ref_text_nlp/text_preprocessing.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> tokenizer = get_tokenizer("basic_english")
# ...

# %%
#Stop word removal
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
tokens1 = [token for token in tokens if token not in stop_words]
print(tokens1)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/phuongnguyen/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/phuongnguyen/Documents/Code Github/deep-learning-pytorch-projects/ref_text_nlp/text_preprocessing.ipynb Cell 8 line 6
#       <a href='vscode-notebook-cell:/Users/phuongnguyen/Documents/Code%20Github/deep-learning-pytorch-projects/ref_text_nlp/text_preprocessing.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> from nltk.corpus import stopwords
#       <a href='vscode-notebook-cell:/Users/phuongnguyen/Documents/Code%20Github/deep-learning-pytorch-projects/ref_text_nlp/text_preprocessing.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a> stop_words = set(stopwords.words('english'))
# ...

# %%
#Stemming
import nltk 
from nltk.stem import PorterStemmer 
filtered_sentence = []

# %% [markdown]
# **3. ENCODING**

# %% [markdown]
# **4. DATASET & DATALOADER**
