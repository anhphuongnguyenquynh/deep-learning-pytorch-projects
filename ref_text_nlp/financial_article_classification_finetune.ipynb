# %% [markdown]
# What is transfer learning?
# - Use pre-existing knowledge from one task to a related task
# - Saves time
# - Share expertise
# - Reduces need for large data

# %% [markdown]
# Pre-trained model BERT:
# - BERT: Bidirectional Encoder Representations from Transformers
# - Trained for language modeling
# - Multiple layers of transformers
# - Pre-trained on large texts

# %% [markdown]
# In this project, the main objective is to classifify a sentence whether it is positive or negative. To solve this, fine-tuning pre-trained model BERT.

# %%
pip install --upgrade transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (4.56.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from transformers) (4.67.0)
# Requirement already satisfied: filelock in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from transformers) (0.22.0)
# Requirement already satisfied: numpy>=1.17 in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from transformers) (0.6.2)
# Requirement already satisfied: requests in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from transformers) (0.34.4)
# Requirement already satisfied: packaging>=20.0 in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from transformers) (23.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (3.10)
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
from transformers import BertTokenizer, BertForSequenceClassification
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/phuongnguyen/Documents/Code Github/deep-learning-pytorch-projects/ref_text_nlp/financial_article_classification_finetune.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/Users/phuongnguyen/Documents/Code%20Github/deep-learning-pytorch-projects/ref_text_nlp/financial_article_classification_finetune.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import torch
#       <a href='vscode-notebook-cell:/Users/phuongnguyen/Documents/Code%20Github/deep-learning-pytorch-projects/ref_text_nlp/financial_article_classification_finetune.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> import torch.nn as nn
# ----> <a href='vscode-notebook-cell:/Users/phuongnguyen/Documents/Code%20Github/deep-learning-pytorch-projects/ref_text_nlp/financial_article_classification_finetune.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> from transformers import BertTokenizer, BertForSequenceClassification
#
# ImportError: cannot import name 'BertForSequenceClassification' from 'transformers' (/Users/phuongnguyen/Library/Python/3.9/lib/python/site-packages/transformers/__init__.py)

# %%
texts = ["I love this!", "This is terrible.", "What a great day!", "I hate waiting.", "Absolutely fantastic!"]

labels = [1, 0, 1, 0, 1]  # 1 for positive sentiment, 0 for negative sentiment

# %%
# Load the BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)

# Tokenize your data and return PyTorch tensors
inputs = tokenizer(texts, padding=True, truncation=True, return_tensors="pt", max_length=32)
inputs["labels"] = torch.tensor(labels)

# Setup the optimizer using model parameters
optimizer = torch.optim.AdamW(model.parameters(), lr=0.00001)
model.train()
for epoch in range(2):
    outputs = model(**inputs)
    loss = outputs.loss
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    print(f"Epoch: {epoch+1}, Loss: {loss.item()}")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch: 1, Loss: 0.6281450986862183
# Epoch: 2, Loss: 0.6050376296043396

# %%
text = "I had an awesome day!"

# Tokenize the text and return PyTorch tensors
input_eval = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=32)
outputs_eval = model(**input_eval)

# Convert the output logits to probabilities
predictions = torch.nn.functional.softmax(outputs_eval.logits, dim=-1)

# Display the sentiments
predicted_label = 'positive' if torch.argmax(predictions) > 0 else 'negative'
print(f"Text: {text}\nSentiment: {predicted_label}")
# Out:
# Text: I had an awesome day!
# Sentiment: positive
